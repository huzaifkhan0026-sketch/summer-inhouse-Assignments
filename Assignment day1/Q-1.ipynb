# %%
# Multiple objects
print("Name:", "Huzaif", "Age:", 20)

# Using separator
print("Python", "Java", "C++", sep=" | ")

# Using end
print("Hello", end=" ")
print("World")
# Out:
# Name: Huzaif Age: 20
# Python | Java | C++
# Hello World
