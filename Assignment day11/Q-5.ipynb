# %%
import numpy as np

res1 = np.array([
    [[100, 200], [300, 400]],
    [[500, 600], [700, 800]]
])

for i in res1:
    for j in i:
        for k in j:
            print(k)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
import numpy as np

pd = np.array([
    [[90, 91], [92, 93]],
    [[94, 95], [96, 97]]
])

for element in np.nditer(pd):
    print(element)
# Out:
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
